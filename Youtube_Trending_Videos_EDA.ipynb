# %% [markdown]
# # Youtube Trending Videos EDA

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# #### Loading the Dataset

# %%
df = pd.read_csv('youtube.csv')

# %% [markdown]
# #### Displaying the first 10 rows of the dataset to get a quick look at the dataset

# %%
df.head(10)
# Out:
#    index     video_id trending_date  \
# 0      0  2kyS6SvSYSE      17.14.11
# 1      1  1ZAPwfrtAFY      17.14.11
# 2      2  5qpjK5DgCt4      17.14.11
# 3      3  puqaWrEC7tY      17.14.11
# 4      4  d380meD0W0M      17.14.11
# 5      5  gHZ1Qz0KiKM      17.14.11
# 6      6  39idVpFF7NQ      17.14.11
# 7      7  nc99ccSXST0      17.14.11
# 8      8  jr9QtXwC9vc      17.14.11
# 9      9  TUmyygCMMGA      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
# 5                              2 Weeks with iPhone X               iJustine
# ...

# %% [markdown]
# #### Displaying the total number of rows and columns in the dataset

# %%
rows, columns = df.shape
print(f"This dataset contains {rows} rows and {columns} Columns")
# Out:
# This dataset contains 161470 rows and 18 Columns

# %% [markdown]
# #### Displaying the columns names

# %%
print(df.columns)
# Out:
# Index(['index', 'video_id', 'trending_date', 'title', 'channel_title',
#        'category_id', 'publish_date', 'time_frame', 'published_day_of_week',
#        'publish_country', 'tags', 'views', 'likes', 'dislikes',
#        'comment_count', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed'],
#       dtype='str')

# %% [markdown]
# #### Based on the publicly available Youtube metadata, the meaning of each column in the dataset is as follows:
#
# - index: Row index of the dataset. (Numeric)
# - video_id: Unique identifier of the YouTube video. (Text)
# - trending_date: The date when the video became trending on YouTube. (Date)
# - title: The title of the video. (Text)
# - channel_title: The title of the YouTube channel that published the video. (Text)
# - category_id: The category ID assigned to the video by YouTube. (Numeric)
# - publish_date: The date when the video was published on YouTube. (Date)
# - time_frame: The duration of time the video has been trending on YouTube. (Text)
# - published_day_of_week: The day of the week when the video was published. (Text)
# - publish_country: The country where the video was published. (Text)
# - tags: The tags or keywords associated with the video. (Text)
# - views: The number of views a video has received. (Numeric)
# - likes: The number of likes a video has received. (Numeric)
# - dislikes: The number of dislikes a video has received. (Numeric)
# - comment_count: The number of comments a video has received. (Numeric)
# - comments_disabled: Indicates whether comments are disabled for the video. (Boolean)
# - ratings_disabled: Indicates whether ratings are disabled for the video. (Boolean)
# - video_error_or_removed: Indicates whether the video is unavailable, removed, or has an error. (Boolean)

# %%
df.describe()
# Out:
#               index    category_id         views         likes      dislikes  \
# count  161470.00000  161470.000000  1.614700e+05  1.614700e+05  1.614700e+05
# mean    80734.50000      19.461151  2.419854e+06  6.566194e+04  3.490153e+03
# std     46612.51832       7.432001  1.043749e+07  2.260617e+05  3.114779e+04
# min         0.00000       1.000000  2.230000e+02  0.000000e+00  0.000000e+00
# 25%     40367.25000      15.000000  1.015382e+05  1.975000e+03  8.500000e+01
# 50%     80734.50000      23.000000  3.847395e+05  9.840000e+03  3.480000e+02
# 75%    121101.75000      24.000000  1.339528e+06  4.006275e+04  1.350000e+03
# max    161469.00000      44.000000  4.245389e+08  5.613827e+06  1.944971e+06
#
#        comment_count
# count   1.614700e+05
# mean    7.035494e+03
# std     3.404121e+04
# min     0.000000e+00
# 25%     2.790000e+02
# 50%     1.144000e+03
# 75%     4.144750e+03
# max     1.626501e+06

# %% [markdown]
# #### Displaying the columns along with their data types

# %%
print(df.dtypes)
# Out:
# index                     int64
# video_id                    str
# trending_date               str
# title                       str
# channel_title               str
# category_id               int64
# publish_date                str
# time_frame                  str
# published_day_of_week       str
# publish_country             str
# tags                        str
# views                     int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# comments_disabled          bool
# ratings_disabled           bool
# video_error_or_removed     bool
# dtype: object

# %% [markdown]
# #### Obersvations on Data Types Clearly Some columns in the dataset are **not in the proper data type** for analysis.
#
# - trending_date is stored as str but should be datetime.
# - publish_date is stored as str but should be datetime.
#
# These columns will need **cleaning and type conversion** before the analysis.

# %% [markdown]
# #### Checking all the unique values of each of the column

# %%
for col in df.columns:
    unique_vals = df[col].unique()
    print(f"Column Name : {col}")
    print(f"Number of unique values : {len(unique_vals)}")
    print(f"All unique values : {unique_vals}")
    print('-'*50)
# Out:
# Column Name : index
# Number of unique values : 161470
# All unique values : [     0      1      2 ... 161467 161468 161469]
# --------------------------------------------------
# Column Name : video_id
# Number of unique values : 55886
# All unique values : <StringArray>
# ['2kyS6SvSYSE', '1ZAPwfrtAFY', '5qpjK5DgCt4', 'puqaWrEC7tY', 'd380meD0W0M',
#  'gHZ1Qz0KiKM', '39idVpFF7NQ', 'nc99ccSXST0', 'jr9QtXwC9vc', 'TUmyygCMMGA',
#  ...
#  'VI4NZW8q6nU', 'Tmv5f02jA5U', 'xxbkfmYFxnw', 'sbxP1ndw2ds', 'FoOi-oTaIEU',
#  '7E1np354AEc', 'sGolxsMSGfQ', '8HNuRNi8t70', 'lbMKLzQ4cNQ', 'POTgw38-m58']
# Length: 55886, dtype: str
# --------------------------------------------------
# Column Name : trending_date
# Number of unique values : 205
# All unique values : <StringArray>
# ['17.14.11', '17.15.11', '17.16.11', '17.17.11', '17.18.11', '17.19.11',
#  '17.20.11', '17.21.11', '17.22.11', '17.23.11',
#  ...
#  '18.05.06', '18.06.06', '18.07.06', '18.08.06', '18.09.06', '18.10.06',
# ...

# %% [markdown]
# #### Summary from the observations
#
# - Columns with correct types:
# index, video_id, title, channel_title, category_id, time_frame, published_day_of_week, publish_country, tags, views, likes, dislikes, comment_count, comments_disabled, ratings_disabled, video_error_or_removed are mostly fine.
#
# - Columns needing conversions/cleaning:
# trending_date, publish_date (stored as str instead of datetime).
#
# - Columns with potential anomalies / considerations:
#   - trending_date – unusual format DD.MM.YY which may require parsing.
#   - publish_date – inconsistent formats (e.g., 13/11/2017, 31/12/2012) and older dates.
#   - tags – contains very long strings, multiple entries separated by |, may require cleaning for analysis.
#   - views, likes, dislikes, comment_count – large numeric ranges, check for outliers or zeros if needed.
#   - publish_country – only 4 countries, may need standardization.
